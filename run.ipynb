# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv('sales_iot_premium_subscription_upgrade_propensity_80k.csv')  # Load data from a CSV file

# %%
data
# Out:
#            Account_ID         Base_Hardware  Connected_Device_Count  \
# 0      IOT_ACC_000001        Smart_Cam_Solo                       3
# 1      IOT_ACC_000002  Video_Doorbell_Basic                       2
# 2      IOT_ACC_000003        Smart_Cam_Solo                       2
# 3      IOT_ACC_000004      Multi_Sensor_Hub                       6
# 4      IOT_ACC_000005  Video_Doorbell_Basic                       3
# ...               ...                   ...                     ...
# 79995  IOT_ACC_079996  Video_Doorbell_Basic                       5
# 79996  IOT_ACC_079997  Video_Doorbell_Basic                       3
# 79997  IOT_ACC_079998      Multi_Sensor_Hub                       2
# 79998  IOT_ACC_079999      Multi_Sensor_Hub                       2
# 79999  IOT_ACC_080000        Smart_Cam_Solo                       2
#
#        Avg_Monthly_Data_Usage_GB  Data_Tier_Ceiling_Hits_6M  \
# 0                           2.48                          2
# ...
